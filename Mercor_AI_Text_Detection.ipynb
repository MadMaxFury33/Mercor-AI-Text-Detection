# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
train = pd.read_csv('/content/train.csv')
test = pd.read_csv('/content/test.csv')

# %%
train.head()
# Out:
#                  id                                              topic  \
# 0  scr_cd3edac7d322  A girl wakes from a dream and she is not sure ...
# 1  scr_86f1104afb28  A journalistic review piece about the top 6 ai...
# 2  scr_c461dafbe886  The influence of fictional universities in cam...
# 3  scr_64880cce429f                           Why do girls love horses
# 4  scr_c7742a3b2444  Every year, a remote mountain town elects a ne...
#
#                                               answer  is_cheating
# 0  My eyes flew open, and the air around me feels...            1
# 1  Robot Butlers in the year of 2025. What are th...            0
# 2  In recent years, apparel featuring the names a...            1
# 3  The moment before I hit the dirt, I thought we...            0
# 4  In the valley of Eldermist, were the mountains...            1

# %%
print('Number of Rows', train.shape[0])
print('Number of Columns', train.shape[1])
# Out:
# Number of Rows 269
# Number of Columns 4

# %%
train.dtypes
# Out:
# id             object
# topic          object
# answer         object
# is_cheating     int64
# dtype: object

# %%
#Text Cleaning & Preprocessing

#Remove unnecessary noise:

import re

def clean_text(text):
    text = re.sub(r'\n', ' ', text)
    text = re.sub(r'[^A-Za-z0-9.,!?;:()\'\" ]', '', text)
    text = re.sub(r'\s+', ' ', text).strip()
    return text

train["clean_text"] = train["answer"].apply(clean_text)
test["clean_text"]  = test["answer"].apply(clean_text)

# %%
#Feature Extraction (TF-IDF)

#Convert text into numerical features for ML models:


from sklearn.feature_extraction.text import TfidfVectorizer

vectorizer = TfidfVectorizer(
    max_features=10000,
    ngram_range=(1,2),
    stop_words='english'
)

X_train = vectorizer.fit_transform(train["clean_text"])
X_test  = vectorizer.transform(test["clean_text"])
y_train = train["is_cheating"]

# %%
#Model Training

from sklearn.linear_model import LogisticRegression
from sklearn.metrics import f1_score, accuracy_score, r2_score
from sklearn.model_selection import train_test_split

X_tr, X_val, y_tr, y_val = train_test_split(X_train, y_train, test_size=0.2, random_state=42)

model = LogisticRegression(max_iter=1000)
model.fit(X_tr, y_tr)

y_pred = model.predict(X_val)
print("Validation Accuracy:", accuracy_score(y_val, y_pred))
print("Validation F1:", f1_score(y_val, y_pred))
print('r2 score',r2_score(y_val, y_pred))
# Out:
# Validation Accuracy: 0.5370370370370371
# Validation F1: 0.6575342465753424
# r2 score -0.8749999999999991

# %%
from xgboost import XGBClassifier
from sklearn.metrics import accuracy_score, f1_score

xgb = XGBClassifier(
    n_estimators=800,
    learning_rate=0.05,
    max_depth=6,
    subsample=0.9,
    colsample_bytree=0.8,
    min_child_weight=3,
    eval_metric='logloss',
    random_state=42,
    n_jobs=-1
)

xgb.fit(X_tr, y_tr)
y_pred = xgb.predict(X_val)

print("Validation Accuracy:", accuracy_score(y_val, y_pred))
print("Validation F1:", f1_score(y_val, y_pred))
# Out:
# Validation Accuracy: 0.6666666666666666
# Validation F1: 0.6785714285714286

# %%
y_test_pred = xgb.predict(X_test)

submission = pd.read_csv("/content/sample_submission.csv")
submission["is_cheating"] = y_test_pred
submission.to_csv("submission.csv", index=False)

# %%
# !pip install optuna
# Out:
# Collecting optuna
#   Downloading optuna-4.6.0-py3-none-any.whl.metadata (17 kB)
# Requirement already satisfied: alembic>=1.5.0 in /usr/local/lib/python3.12/dist-packages (from optuna) (1.17.1)
# Collecting colorlog (from optuna)
#   Downloading colorlog-6.10.1-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from optuna) (2.0.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from optuna) (25.0)
# Requirement already satisfied: sqlalchemy>=1.4.2 in /usr/local/lib/python3.12/dist-packages (from optuna) (2.0.44)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (from optuna) (4.67.1)
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.12/dist-packages (from optuna) (6.0.3)
# Requirement already satisfied: Mako in /usr/local/lib/python3.12/dist-packages (from alembic>=1.5.0->optuna) (1.3.10)
# Requirement already satisfied: typing-extensions>=4.12 in /usr/local/lib/python3.12/dist-packages (from alembic>=1.5.0->optuna) (4.15.0)
# Requirement already satisfied: greenlet>=1 in /usr/local/lib/python3.12/dist-packages (from sqlalchemy>=1.4.2->optuna) (3.2.4)
# Requirement already satisfied: MarkupSafe>=0.9.2 in /usr/local/lib/python3.12/dist-packages (from Mako->alembic>=1.5.0->optuna) (3.0.3)
# Downloading optuna-4.6.0-py3-none-any.whl (404 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 404.7/404.7 kB 6.0 MB/s eta 0:00:00
# Downloading colorlog-6.10.1-py3-none-any.whl (11 kB)
# Installing collected packages: colorlog, optuna
# Successfully installed colorlog-6.10.1 optuna-4.6.0

# %%
import optuna
from xgboost import XGBClassifier
from sklearn.model_selection import cross_val_score

def objective(trial):
    params = {
        "n_estimators": trial.suggest_int("n_estimators", 500, 2500),
        "max_depth": trial.suggest_int("max_depth", 3, 12),
        "learning_rate": trial.suggest_float("learning_rate", 0.01, 0.3),
        "subsample": trial.suggest_float("subsample", 0.6, 1.0),
        "colsample_bytree": trial.suggest_float("colsample_bytree", 0.6, 1.0),
        "min_child_weight": trial.suggest_int("min_child_weight", 1, 10),
        "gamma": trial.suggest_float("gamma", 0, 1.0),
        "eval_metric": "logloss",
        "random_state": 42,
        "n_jobs": -1
    }
    model = XGBClassifier(**params)
    f1 = cross_val_score(model, X_tr, y_tr, scoring='f1', cv=3).mean()
    return f1

study = optuna.create_study(direction="maximize")
study.optimize(objective, n_trials=50)
print(study.best_params)
# Out:
# [I 2025-11-11 22:49:39,545] A new study created in memory with name: no-name-297af97c-1ef4-426d-8171-9b29dad92496
# [I 2025-11-11 22:50:10,497] Trial 0 finished with value: 0.6798093216393871 and parameters: {'n_estimators': 1896, 'max_depth': 11, 'learning_rate': 0.11032343195675567, 'subsample': 0.7030861651308451, 'colsample_bytree': 0.8239407485241775, 'min_child_weight': 4, 'gamma': 0.3629541367897491}. Best is trial 0 with value: 0.6798093216393871.
# [I 2025-11-11 22:50:21,861] Trial 1 finished with value: 0.707009780856751 and parameters: {'n_estimators': 898, 'max_depth': 4, 'learning_rate': 0.10326769688864627, 'subsample': 0.7399243858743987, 'colsample_bytree': 0.7356582264616058, 'min_child_weight': 6, 'gamma': 0.12982668660768137}. Best is trial 1 with value: 0.707009780856751.
# [I 2025-11-11 22:50:26,137] Trial 2 finished with value: 0.7807448688674743 and parameters: {'n_estimators': 1010, 'max_depth': 6, 'learning_rate': 0.17437032739957767, 'subsample': 0.8056743773525297, 'colsample_bytree': 0.8061275561544542, 'min_child_weight': 2, 'gamma': 0.8284046560711474}. Best is trial 2 with value: 0.7807448688674743.
# [I 2025-11-11 22:50:28,162] Trial 3 finished with value: 0.683118356402531 and parameters: {'n_estimators': 528, 'max_depth': 8, 'learning_rate': 0.08922572024622644, 'subsample': 0.9553830359996043, 'colsample_bytree': 0.929590977763233, 'min_child_weight': 6, 'gamma': 0.838482991231136}. Best is trial 2 with value: 0.7807448688674743.
# [I 2025-11-11 22:50:31,283] Trial 4 finished with value: 0.721031746031746 and parameters: {'n_estimators': 755, 'max_depth': 12, 'learning_rate': 0.12779228446601468, 'subsample': 0.7380044450383916, 'colsample_bytree': 0.9134156969193659, 'min_child_weight': 3, 'gamma': 0.6317175090028437}. Best is trial 2 with value: 0.7807448688674743.
# [I 2025-11-11 22:50:35,563] Trial 5 finished with value: 0.6710135409825811 and parameters: {'n_estimators': 993, 'max_depth': 12, 'learning_rate': 0.1854802324924188, 'subsample': 0.7899712629685193, 'colsample_bytree': 0.8029889816122437, 'min_child_weight': 7, 'gamma': 0.7990823108982067}. Best is trial 2 with value: 0.7807448688674743.
# [I 2025-11-11 22:50:41,329] Trial 6 finished with value: 0.7113323500491641 and parameters: {'n_estimators': 1948, 'max_depth': 11, 'learning_rate': 0.1869853472121132, 'subsample': 0.7370805797521742, 'colsample_bytree': 0.8295813761211793, 'min_child_weight': 9, 'gamma': 0.6739817096764021}. Best is trial 2 with value: 0.7807448688674743.
# [I 2025-11-11 22:50:43,786] Trial 7 finished with value: 0.7234173496398868 and parameters: {'n_estimators': 690, 'max_depth': 6, 'learning_rate': 0.2050987846324398, 'subsample': 0.6678115403090842, 'colsample_bytree': 0.7061052394366737, 'min_child_weight': 2, 'gamma': 0.5313840673703945}. Best is trial 2 with value: 0.7807448688674743.
# [I 2025-11-11 22:50:48,830] Trial 8 finished with value: 0.6971547815218887 and parameters: {'n_estimators': 1190, 'max_depth': 6, 'learning_rate': 0.16375761710303063, 'subsample': 0.8578748869287932, 'colsample_bytree': 0.8199825440783276, 'min_child_weight': 3, 'gamma': 0.8027856197181553}. Best is trial 2 with value: 0.7807448688674743.
# [I 2025-11-11 22:50:51,105] Trial 9 finished with value: 0.7500178095975921 and parameters: {'n_estimators': 794, 'max_depth': 10, 'learning_rate': 0.28768306514101094, 'subsample': 0.7978070389563134, 'colsample_bytree': 0.7212621421734128, 'min_child_weight': 2, 'gamma': 0.7250258082178388}. Best is trial 2 with value: 0.7807448688674743.
# [I 2025-11-11 22:50:57,735] Trial 10 finished with value: 0.8066907719471463 and parameters: {'n_estimators': 1452, 'max_depth': 3, 'learning_rate': 0.011415932536423617, 'subsample': 0.9008510011313646, 'colsample_bytree': 0.6061745955617852, 'min_child_weight': 1, 'gamma': 0.9687924309515157}. Best is trial 10 with value: 0.8066907719471463.
# [I 2025-11-11 22:51:02,810] Trial 11 finished with value: 0.8037029101357551 and parameters: {'n_estimators': 1474, 'max_depth': 3, 'learning_rate': 0.017524167874994546, 'subsample': 0.90321535913423, 'colsample_bytree': 0.6228202153315916, 'min_child_weight': 1, 'gamma': 0.976460822792964}. Best is trial 10 with value: 0.8066907719471463.
# [I 2025-11-11 22:51:08,757] Trial 12 finished with value: 0.8068036853295535 and parameters: {'n_estimators': 1435, 'max_depth': 3, 'learning_rate': 0.011515983695273046, 'subsample': 0.936639108701616, 'colsample_bytree': 0.6013188642943106, 'min_child_weight': 1, 'gamma': 0.9990897632473751}. Best is trial 12 with value: 0.8068036853295535.
# [I 2025-11-11 22:51:16,389] Trial 13 finished with value: 0.8149316177982567 and parameters: {'n_estimators': 2469, 'max_depth': 3, 'learning_rate': 0.03214431680918202, 'subsample': 0.9945352236021422, 'colsample_bytree': 0.6039810589085715, 'min_child_weight': 1, 'gamma': 0.9681579363337571}. Best is trial 13 with value: 0.8149316177982567.
# [I 2025-11-11 22:51:24,130] Trial 14 finished with value: 0.6987822475627353 and parameters: {'n_estimators': 2452, 'max_depth': 4, 'learning_rate': 0.04886329067032686, 'subsample': 0.9893924023435704, 'colsample_bytree': 0.6654490777380129, 'min_child_weight': 4, 'gamma': 0.306749942475831}. Best is trial 13 with value: 0.8149316177982567.
# [I 2025-11-11 22:51:29,746] Trial 15 finished with value: 0.7348218572937674 and parameters: {'n_estimators': 2383, 'max_depth': 5, 'learning_rate': 0.06227793054226771, 'subsample': 0.997131552254556, 'colsample_bytree': 0.6654527538738455, 'min_child_weight': 4, 'gamma': 0.9701006493644249}. Best is trial 13 with value: 0.8149316177982567.
# [I 2025-11-11 22:51:39,953] Trial 16 finished with value: 0.6577169544911481 and parameters: {'n_estimators': 1858, 'max_depth': 8, 'learning_rate': 0.06187633724609543, 'subsample': 0.9311557090740917, 'colsample_bytree': 0.9905210902279178, 'min_child_weight': 9, 'gamma': 0.04160735290046369}. Best is trial 13 with value: 0.8149316177982567.
# [I 2025-11-11 22:51:49,110] Trial 17 finished with value: 0.807798080472499 and parameters: {'n_estimators': 2137, 'max_depth': 3, 'learning_rate': 0.2510619687505516, 'subsample': 0.8562320409418565, 'colsample_bytree': 0.6587408859289517, 'min_child_weight': 1, 'gamma': 0.537590163546761}. Best is trial 13 with value: 0.8149316177982567.
# [I 2025-11-11 22:51:53,932] Trial 18 finished with value: 0.7278234302570586 and parameters: {'n_estimators': 2188, 'max_depth': 5, 'learning_rate': 0.24660839474994994, 'subsample': 0.6072897539296633, 'colsample_bytree': 0.6590757997163421, 'min_child_weight': 10, 'gamma': 0.4193327325104698}. Best is trial 13 with value: 0.8149316177982567.
# [I 2025-11-11 22:52:02,087] Trial 19 finished with value: 0.6807124518613609 and parameters: {'n_estimators': 2167, 'max_depth': 7, 'learning_rate': 0.2335202365539734, 'subsample': 0.858709270363876, 'colsample_bytree': 0.7525161466518213, 'min_child_weight': 3, 'gamma': 0.24373200651715188}. Best is trial 13 with value: 0.8149316177982567.
# [I 2025-11-11 22:52:09,164] Trial 20 finished with value: 0.6660364145658263 and parameters: {'n_estimators': 2200, 'max_depth': 4, 'learning_rate': 0.29294413218914983, 'subsample': 0.83558884340796, 'colsample_bytree': 0.6771844654027012, 'min_child_weight': 5, 'gamma': 0.5327745935193877}. Best is trial 13 with value: 0.8149316177982567.
# [I 2025-11-11 22:52:13,473] Trial 21 finished with value: 0.7989605480746516 and parameters: {'n_estimators': 1649, 'max_depth': 3, 'learning_rate': 0.03633230815075636, 'subsample': 0.9419173210997104, 'colsample_bytree': 0.6088605789939908, 'min_child_weight': 1, 'gamma': 0.9197763596819807}. Best is trial 13 with value: 0.8149316177982567.
# [I 2025-11-11 22:52:17,013] Trial 22 finished with value: 0.8128460686600222 and parameters: {'n_estimators': 1265, 'max_depth': 3, 'learning_rate': 0.07946655841783001, 'subsample': 0.8987883109115253, 'colsample_bytree': 0.6349454799292513, 'min_child_weight': 1, 'gamma': 0.9119772861032895}. Best is trial 13 with value: 0.8149316177982567.
# [I 2025-11-11 22:52:22,481] Trial 23 finished with value: 0.7918261214875741 and parameters: {'n_estimators': 1686, 'max_depth': 5, 'learning_rate': 0.13734203698255285, 'subsample': 0.8784142425374758, 'colsample_bytree': 0.6385782841759811, 'min_child_weight': 2, 'gamma': 0.8834122959078831}. Best is trial 13 with value: 0.8149316177982567.
# [I 2025-11-11 22:52:26,438] Trial 24 finished with value: 0.8088952654232425 and parameters: {'n_estimators': 1275, 'max_depth': 4, 'learning_rate': 0.07921046592378848, 'subsample': 0.9701990014050778, 'colsample_bytree': 0.6885683355252552, 'min_child_weight': 1, 'gamma': 0.6257679129651835}. Best is trial 13 with value: 0.8149316177982567.
# [I 2025-11-11 22:52:30,430] Trial 25 finished with value: 0.783595668812677 and parameters: {'n_estimators': 1261, 'max_depth': 4, 'learning_rate': 0.08086936574963971, 'subsample': 0.9744693390717084, 'colsample_bytree': 0.7617422805328808, 'min_child_weight': 2, 'gamma': 0.7349061953515011}. Best is trial 13 with value: 0.8149316177982567.
# [I 2025-11-11 22:52:35,303] Trial 26 finished with value: 0.7309025505281886 and parameters: {'n_estimators': 1216, 'max_depth': 4, 'learning_rate': 0.07508339650744189, 'subsample': 0.9074176319892442, 'colsample_bytree': 0.6967611406531123, 'min_child_weight': 3, 'gamma': 0.6132287313602542}. Best is trial 13 with value: 0.8149316177982567.
# [I 2025-11-11 22:52:39,331] Trial 27 finished with value: 0.7947047449055482 and parameters: {'n_estimators': 1271, 'max_depth': 9, 'learning_rate': 0.032938114147485535, 'subsample': 0.9673871024831242, 'colsample_bytree': 0.639245827243742, 'min_child_weight': 1, 'gamma': 0.8889988735261668}. Best is trial 13 with value: 0.8149316177982567.
# [I 2025-11-11 22:52:44,835] Trial 28 finished with value: 0.6852199291223681 and parameters: {'n_estimators': 1640, 'max_depth': 5, 'learning_rate': 0.13693908176776765, 'subsample': 0.9211743946382933, 'colsample_bytree': 0.6907207931675053, 'min_child_weight': 5, 'gamma': 0.7125278239136001}. Best is trial 13 with value: 0.8149316177982567.
# [I 2025-11-11 22:52:47,793] Trial 29 finished with value: 0.6916504865344559 and parameters: {'n_estimators': 1115, 'max_depth': 7, 'learning_rate': 0.10824361393106655, 'subsample': 0.9949486102774394, 'colsample_bytree': 0.7748660454829126, 'min_child_weight': 7, 'gamma': 0.412748831036206}. Best is trial 13 with value: 0.8149316177982567.
# [I 2025-11-11 22:52:52,502] Trial 30 finished with value: 0.7543793415886438 and parameters: {'n_estimators': 1871, 'max_depth': 3, 'learning_rate': 0.09229601933039219, 'subsample': 0.9648380559114274, 'colsample_bytree': 0.637177781379832, 'min_child_weight': 3, 'gamma': 0.7767955303982125}. Best is trial 13 with value: 0.8149316177982567.
# [I 2025-11-11 22:52:58,963] Trial 31 finished with value: 0.8106676521310668 and parameters: {'n_estimators': 2364, 'max_depth': 3, 'learning_rate': 0.26124784701954396, 'subsample': 0.8774333694131594, 'colsample_bytree': 0.6464448799868263, 'min_child_weight': 1, 'gamma': 0.46812422475352294}. Best is trial 13 with value: 0.8149316177982567.
# [I 2025-11-11 22:53:06,796] Trial 32 finished with value: 0.7391237423561843 and parameters: {'n_estimators': 2420, 'max_depth': 4, 'learning_rate': 0.12453834665679336, 'subsample': 0.8900000561167056, 'colsample_bytree': 0.6335315477461042, 'min_child_weight': 2, 'gamma': 0.24302080107407098}. Best is trial 13 with value: 0.8149316177982567.
# [I 2025-11-11 22:53:13,566] Trial 33 finished with value: 0.8314383073419217 and parameters: {'n_estimators': 2321, 'max_depth': 4, 'learning_rate': 0.04888609400923406, 'subsample': 0.8300327083716164, 'colsample_bytree': 0.706826227432627, 'min_child_weight': 1, 'gamma': 0.434722948436092}. Best is trial 33 with value: 0.8314383073419217.
# [I 2025-11-11 22:53:21,936] Trial 34 finished with value: 0.7616422624174563 and parameters: {'n_estimators': 2343, 'max_depth': 3, 'learning_rate': 0.04371270194926798, 'subsample': 0.8300918262035927, 'colsample_bytree': 0.7290096744783244, 'min_child_weight': 2, 'gamma': 0.4181788032290473}. Best is trial 33 with value: 0.8314383073419217.
# [I 2025-11-11 22:53:28,078] Trial 35 finished with value: 0.8212982649552458 and parameters: {'n_estimators': 2015, 'max_depth': 5, 'learning_rate': 0.06058267930959625, 'subsample': 0.7643794496252223, 'colsample_bytree': 0.6489651352998108, 'min_child_weight': 1, 'gamma': 0.4733380019393049}. Best is trial 33 with value: 0.8314383073419217.
# [I 2025-11-11 22:53:35,888] Trial 36 finished with value: 0.7447842732395578 and parameters: {'n_estimators': 2047, 'max_depth': 6, 'learning_rate': 0.06249022273045245, 'subsample': 0.7764434411046363, 'colsample_bytree': 0.6207211180117048, 'min_child_weight': 2, 'gamma': 0.3090387769168239}. Best is trial 33 with value: 0.8314383073419217.
# [I 2025-11-11 22:53:47,020] Trial 37 finished with value: 0.6870394459446124 and parameters: {'n_estimators': 2494, 'max_depth': 5, 'learning_rate': 0.02749567174636336, 'subsample': 0.7041355087826044, 'colsample_bytree': 0.8976736784314217, 'min_child_weight': 4, 'gamma': 0.5903018165604788}. Best is trial 33 with value: 0.8314383073419217.
# [I 2025-11-11 22:53:55,664] Trial 38 finished with value: 0.7527275337352858 and parameters: {'n_estimators': 2291, 'max_depth': 4, 'learning_rate': 0.09912111163102898, 'subsample': 0.7648921502013143, 'colsample_bytree': 0.8646079938226952, 'min_child_weight': 2, 'gamma': 0.46942790346881685}. Best is trial 33 with value: 0.8314383073419217.
# [I 2025-11-11 22:54:02,073] Trial 39 finished with value: 0.6682479500218624 and parameters: {'n_estimators': 2019, 'max_depth': 6, 'learning_rate': 0.0512223202960165, 'subsample': 0.8211089242536759, 'colsample_bytree': 0.7100462357517978, 'min_child_weight': 7, 'gamma': 0.19055827045899382}. Best is trial 33 with value: 0.8314383073419217.
# [I 2025-11-11 22:54:10,676] Trial 40 finished with value: 0.7056240647493802 and parameters: {'n_estimators': 2301, 'max_depth': 5, 'learning_rate': 0.11787101477539877, 'subsample': 0.7561531725390308, 'colsample_bytree': 0.7814072092879868, 'min_child_weight': 3, 'gamma': 0.3584989879194545}. Best is trial 33 with value: 0.8314383073419217.
# [I 2025-11-11 22:54:18,331] Trial 41 finished with value: 0.8117768846669101 and parameters: {'n_estimators': 2260, 'max_depth': 3, 'learning_rate': 0.06751976466782472, 'subsample': 0.7175173207640086, 'colsample_bytree': 0.6563855286011026, 'min_child_weight': 1, 'gamma': 0.4597935804625185}. Best is trial 33 with value: 0.8314383073419217.
# [I 2025-11-11 22:54:23,351] Trial 42 finished with value: 0.807146448322919 and parameters: {'n_estimators': 1775, 'max_depth': 4, 'learning_rate': 0.06872881834455509, 'subsample': 0.7133577819242007, 'colsample_bytree': 0.6736691582253959, 'min_child_weight': 1, 'gamma': 0.4798743769011614}. Best is trial 33 with value: 0.8314383073419217.
# [I 2025-11-11 22:54:31,838] Trial 43 finished with value: 0.7665371727608902 and parameters: {'n_estimators': 2055, 'max_depth': 3, 'learning_rate': 0.029107383127134047, 'subsample': 0.6795793801533175, 'colsample_bytree': 0.6155973450324277, 'min_child_weight': 2, 'gamma': 0.34878681918326015}. Best is trial 33 with value: 0.8314383073419217.
# [I 2025-11-11 22:54:37,848] Trial 44 finished with value: 0.8233933022061145 and parameters: {'n_estimators': 2250, 'max_depth': 4, 'learning_rate': 0.05244176571608149, 'subsample': 0.725933947451461, 'colsample_bytree': 0.6502734992368614, 'min_child_weight': 1, 'gamma': 0.5629642322435181}. Best is trial 33 with value: 0.8314383073419217.
# [I 2025-11-11 22:54:43,816] Trial 45 finished with value: 0.8240225268891659 and parameters: {'n_estimators': 1374, 'max_depth': 4, 'learning_rate': 0.04042196783771097, 'subsample': 0.811084036422242, 'colsample_bytree': 0.7431107787147511, 'min_child_weight': 1, 'gamma': 0.8487832311012373}. Best is trial 33 with value: 0.8314383073419217.
# [I 2025-11-11 22:54:49,839] Trial 46 finished with value: 0.756326647799516 and parameters: {'n_estimators': 1962, 'max_depth': 6, 'learning_rate': 0.04666450403330027, 'subsample': 0.7333860176980952, 'colsample_bytree': 0.7430943001644282, 'min_child_weight': 2, 'gamma': 0.8579042014990221}. Best is trial 33 with value: 0.8314383073419217.
# [I 2025-11-11 22:54:57,486] Trial 47 finished with value: 0.8326051458581579 and parameters: {'n_estimators': 1392, 'max_depth': 5, 'learning_rate': 0.019790837837224864, 'subsample': 0.6734998627615472, 'colsample_bytree': 0.7175557769418476, 'min_child_weight': 1, 'gamma': 0.6841847920968599}. Best is trial 47 with value: 0.8326051458581579.
# [I 2025-11-11 22:55:04,611] Trial 48 finished with value: 0.7066293183940243 and parameters: {'n_estimators': 1386, 'max_depth': 5, 'learning_rate': 0.019663320895357085, 'subsample': 0.6442257482144156, 'colsample_bytree': 0.7215167648196472, 'min_child_weight': 3, 'gamma': 0.6650780436990844}. Best is trial 47 with value: 0.8326051458581579.
# [I 2025-11-11 22:55:10,208] Trial 49 finished with value: 0.8056151165907264 and parameters: {'n_estimators': 1562, 'max_depth': 7, 'learning_rate': 0.052189589300487275, 'subsample': 0.6807333800700262, 'colsample_bytree': 0.789250735957045, 'min_child_weight': 1, 'gamma': 0.5724796412240015}. Best is trial 47 with value: 0.8326051458581579.
# {'n_estimators': 1392, 'max_depth': 5, 'learning_rate': 0.019790837837224864, 'subsample': 0.6734998627615472, 'colsample_bytree': 0.7175557769418476, 'min_child_weight': 1, 'gamma': 0.6841847920968599}

# %%
xgb1 = XGBClassifier(n_estimators=1392, max_depth=5, learning_rate=0.019790837837224864, subsample=0.6734998627615472, colsample_bytree=0.7175557769418476, min_child_weight=1, gamma=0.6841847920968599)
xgb1.fit(X_tr, y_tr)
y_pred = xgb1.predict(X_val)

print("Validation Accuracy:", accuracy_score(y_val, y_pred))
print("Validation F1:", f1_score(y_val, y_pred))
# Out:
# Validation Accuracy: 0.7592592592592593
# Validation F1: 0.7719298245614035

# %%
#submission
prediction = xgb1.predict(X_test)

# %%
y_test_pred = xgb1.predict(X_test)

submission = pd.read_csv("/content/sample_submission.csv")
submission["is_cheating"] = y_test_pred
submission.to_csv("submission.csv", index=False)
